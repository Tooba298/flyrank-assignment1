# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# **Chosen Lane:** Refresh / Content Opportunity Scoring
#
# For this project, I selected the **Refresh / Content Opportunity Scoring** lane.
#
# The ML task is best described as a **scoring/ranking problem**. Instead of predicting a simple yes/no answer, the goal is to assign each content page a refresh score so that pages can be ranked from highest priority to lowest priority for review.
#
# Each row in the dataset represents one content page, and the output will help content reviewers decide which pages should be reviewed first.

# %%
task_type = "Scoring / Ranking"

print("Chosen Lane: Refresh / Content Opportunity Scoring")
print("ML Task Type:", task_type)
# Out:
# Chosen Lane: Refresh / Content Opportunity Scoring
# ML Task Type: Scoring / Ranking

# %% [markdown]
# ## 2. Target or proxy
#
# The final dataset does not contain a direct column called "Needs Refresh", so a proxy target will be used.
#
# One possible proxy is identifying pages with declining search performance based on available search and engagement signals.
#
# The ML model would learn patterns from these signals and assign each page a refresh score rather than making a simple rule-based decision.

# %%
target = "Refresh Score (Proxy)"

print("Target:", target)
# Out:
# Target: Refresh Score (Proxy)

# %% [markdown]
# ## 3. Success metric
#
# The success of this project will be measured by how well the ranking identifies pages that deserve review.
#
# Possible evaluation metrics include:
#
# - Precision@K (how many of the top recommended pages actually deserve review)
# - Recall
# - Ranking quality
#
# From a business perspective, success means reviewers spend more time on valuable pages and less time reviewing pages that do not need updates.

# %%
metric = "Precision@K"

print("Primary Success Metric:", metric)
# Out:
# Primary Success Metric: Precision@K

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# Each row in the dataset represents **one content page**.
#
# The dataframe below shows the first few rows from the starter dataset to demonstrate the unit of analysis.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)

df.head()
# Out:
# Dataset Shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule might recommend reviewing every page with declining traffic.
#
# However, content performance depends on several factors such as impressions, clicks, sessions, engagement, and search trends. Looking at only one feature may result in poor recommendations.
#
# Machine learning can combine multiple signals and assign a score to each page based on patterns found in the data. This helps produce more consistent and useful recommendations than a single manually written rule.
#
# The output supports content reviewers by helping them prioritize which pages should be reviewed first.

# %%
print("ML combines multiple search and engagement signals.")
print("Output: Ranked list of pages for review.")
# Out:
# ML combines multiple search and engagement signals.
# Output: Ranked list of pages for review.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
