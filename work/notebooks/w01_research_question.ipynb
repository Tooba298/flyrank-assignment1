# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This notebook presents my provisional research question, selected project lane, and an initial exploration of the starter dataset. The purpose of this assignment is to define the business problem before building any machine learning model.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **Chosen Lane:** Refresh / Content Opportunity Scoring
#
# I selected the **Refresh / Content Opportunity Scoring** lane because it focuses on helping content teams identify which pages should be reviewed first. Instead of manually reviewing every content page, this project aims to prioritize pages using observable search and engagement signals. This allows reviewers to spend their limited time on pages that are most likely to benefit from review. I chose this lane because it aligns well with the starter dataset and provides a practical business problem that can be improved further throughout the internship.

# %%
lane = 'Refresh / Content Opportunity Scoring'
print('Chosen Lane:', lane)

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ### Research Question
#
# Which content pages should be reviewed first for refresh based on their search performance and engagement signals?
#
# ### Decision
#
# The decision is to identify and prioritize content pages that should be reviewed before others.
#
# ### Action
#
# A content reviewer or SEO team will review the recommended pages and decide whether they should be refreshed, expanded, monitored, or improved.
#
# ### Unit of Analysis
#
# Each row in the dataset represents one content page.
#
# ### Output
#
# The expected output is a ranked list of content pages with refresh scores and reason codes explaining why each page was recommended.
#
# ### Cost of a Wrong Recommendation
#
# If a page is incorrectly recommended (false positive), reviewers spend time reviewing a page that may not need attention.
#
# If an important declining page is missed (false negative), its search performance may continue to decrease, resulting in lost traffic and missed opportunities.
#
# ### Why Data and Machine Learning Help
#
# The dataset contains multiple search and engagement signals that are difficult to evaluate manually across thousands of pages. Data analysis and machine learning can combine these signals to rank pages for review, helping reviewers make faster and more consistent decisions.

# %%
decision = 'Prioritize pages for content review'
action = 'Review, refresh, expand, monitor, or improve the selected page'

print('Decision:', decision)
print('Action:', action)

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The following code loads the starter dataset and calculates a few real statistics that support the selected project lane.

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

print('Total Pages:', len(df))

# Number of pages with declining trend
declining_pages = (df['trend_direction'] == 'down').sum()
print('Declining Pages:', declining_pages)

# Average impressions over the last 90 days
print('Average Impressions (90 Days):', round(df['impressions_90d'].mean(), 2))

# Average sessions over the last 90 days
print('Average Sessions (90 Days):', round(df['sessions_90d'].mean(), 2))
# Out:
# Total Pages: 30000
# Declining Pages: 16262
# Average Impressions (90 Days): 5200.37
# Average Sessions (90 Days): 37.07

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project provides decision-support by identifying pages that may deserve review based on observed search and engagement signals. The recommendations are based on measurable patterns found in the available data and are intended to help prioritize review efforts.
#
# This analysis cannot prove that refreshing a page will improve its performance. It also cannot prove Google's ranking factors or establish cause-and-effect relationships. Any recommendations produced by this project should always be reviewed by a human before action is taken.

# %%
print('Research Question Notebook completed successfully.')

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it.
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all).
# - [x] No client names, URLs, or private queries anywhere.
# - [x] My claims use careful words: observed, measured, directional, decision-support.
# - [x] Committed to my repo under `work/notebooks/` — then submit my repo URL on the assignment card.
